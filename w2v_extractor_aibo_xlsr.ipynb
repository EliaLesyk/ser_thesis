# %%
import pandas as pd
import os
import torch
#import torchaudio
#import requests
#import matplotlib
#import matplotlib.pyplot as plt
#import IPython
#import gc
import numpy as np

from os.path import isfile, join
from scipy.io.wavfile import write, read
from scipy.stats import kurtosis, skew
#from datasets import load_dataset
from tqdm import tqdm
from transformers import Wav2Vec2FeatureExtractor, Wav2Vec2Model, Wav2Vec2ForPreTraining

# %%
#home_path = '/home/hpc/iwi5/iwi5055h/'
home_path = ''
aibo_path = home_path + "data/AIBO/"
save_path = aibo_path + "wav2vec/"

# %%
#device = 'cpu'
#if torch.cuda.is_available():
 #   device = 'cuda'

# %%
def Wav2Vec_Models(file, model_name='xvec', plot=False, cuda=False):

    try:
        fs, audio=read(file)   
        audio=(audio-np.mean(audio))/max(audio)
       
        device='cpu'
        if cuda:
            device='cuda'
       
        #sampling_rate = fs
       
        if model_name=='xlsr':
            feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("facebook/wav2vec2-large-xlsr-53")
            model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-xlsr-53").to(device)
            #model_proj = Wav2Vec2ForPreTraining.from_pretrained("facebook/wav2vec2-large-xlsr-53").to(device)
        elif model_name=='base':
            feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("facebook/wav2vec2-base-960h")   
            model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h").to(device)
            #model_proj = Wav2Vec2ForPreTraining.from_pretrained("facebook/wav2vec2-base-960h").to(device)
        elif model_name=='xvec':
            feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("anton-l/wav2vec2-base-superb-sv")        
            model = Wav2Vec2ForXVector.from_pretrained("anton-l/wav2vec2-base-superb-sv").to(device)
            #model_proj = Wav2Vec2ForPreTraining.from_pretrained("anton-l/wav2vec2-base-superb-sv").to(device)
   
        # audio file is decoded on the fly
        input_values = feature_extractor(np.array(audio, dtype=float), sampling_rate=fs, return_tensors="pt", padding=True).to(device).input_values
        input_values_all = feature_extractor(np.array(audio, dtype=float), sampling_rate=fs, return_tensors="pt", padding=True)
   
        # compute masked indices
        #batch_size, raw_sequence_length = input_values.shape
        #sequence_length = model._get_feat_extract_output_lengths(raw_sequence_length)
        #mask_time_indices = _compute_mask_indices((batch_size, sequence_length), mask_prob=0.2, mask_length=2)
        #mask_time_indices = torch.tensor(mask_time_indices, device=input_values.device, dtype=torch.long)
       
        with torch.inference_mode():
           
            tmp = model(**input_values_all.to(device))
            #tmp_proj=model_proj(input_values.to(device), mask_time_indices=mask_time_indices.to(device) )
            if model_name=='xvec':
                last_hidden_states = tmp.embeddings.cpu()
                #last_hiddens=np.hstack((last_hiddens_avg,last_hiddens_std,last_hiddens_skew,last_hiddens_kurt,last_hiddens_min,last_hiddens_max))
               
                features = tmp.logits.cpu()
                #features = np.hstack((features,features_std,features_skew,features_kurt,features_min,features_max))
   
                #last_hiddens_avg=np.array(torch.mean(tmp_proj.projected_states, dim=1).cpu())
                #last_hiddens_std=np.array(torch.std(tmp_proj.projected_states, dim=1).cpu())
                #last_hiddens_skew=skew(np.array(tmp_proj.projected_states.cpu()), axis=1)
                #last_hiddens_kurt=kurtosis(np.array(tmp_proj.projected_states.cpu()), axis=1)
                #last_hiddens_min=np.array(torch.min(tmp_proj.projected_states, dim=1)[0].cpu())
                #last_hiddens_max=np.array(torch.max(tmp_proj.projected_states, dim=1)[0].cpu())
                #last_hiddens_proj=np.hstack((last_hiddens_avg,last_hiddens_std,last_hiddens_skew,last_hiddens_kurt,last_hiddens_min,last_hiddens_max))
               
               
                #features_avg=np.array(torch.mean(tmp_proj.projected_quantized_states, dim=1).cpu())
                #features_std=np.array(torch.std(tmp_proj.projected_quantized_states, dim=1).cpu())
                #features_skew=skew(np.array(tmp_proj.projected_quantized_states.cpu()), axis=1)
                #features_kurt=kurtosis(np.array(tmp_proj.projected_quantized_states.cpu()), axis=1)
                #features_min=np.array(torch.min(tmp_proj.projected_quantized_states, dim=1)[0].cpu())
                #features_max=np.array(torch.max(tmp_proj.projected_quantized_states, dim=1)[0].cpu())
                #features_proj = np.hstack((features_avg,features_std,features_skew,features_kurt,features_min,features_max))
           
            else:
                last_hiddens_avg=np.array(torch.mean(tmp.last_hidden_state, dim=1).cpu())
                last_hiddens_std=np.array(torch.std(tmp.last_hidden_state, dim=1).cpu())
                last_hiddens_skew=skew(np.array(tmp.last_hidden_state.cpu()), axis=1)
                last_hiddens_kurt=kurtosis(np.array(tmp.last_hidden_state.cpu()), axis=1)
                last_hiddens_min=np.array(torch.min(tmp.last_hidden_state, dim=1)[0].cpu())
                last_hiddens_max=np.array(torch.max(tmp.last_hidden_state, dim=1)[0].cpu())
           
                last_hidden_states=np.hstack((last_hiddens_avg,last_hiddens_std,last_hiddens_skew,last_hiddens_kurt,last_hiddens_min,last_hiddens_max))
               
                features_avg=np.array(torch.mean(tmp.extract_features, dim=1).cpu())
                features_std=np.array(torch.std(tmp.extract_features, dim=1).cpu())
                features_skew=skew(np.array(tmp.extract_features.cpu()), axis=1)
                features_kurt=kurtosis(np.array(tmp.extract_features.cpu()), axis=1)
                features_min=np.array(torch.min(tmp.extract_features, dim=1)[0].cpu())
                features_max=np.array(torch.max(tmp.extract_features, dim=1)[0].cpu())
               
                features = np.hstack((features_avg,features_std,features_skew,features_kurt,features_min,features_max))
   
                #last_hiddens_avg=np.array(torch.mean(tmp_proj.projected_states, dim=1).cpu())
                #last_hiddens_std=np.array(torch.std(tmp_proj.projected_states, dim=1).cpu())
                #last_hiddens_skew=skew(np.array(tmp_proj.projected_states.cpu()), axis=1)
                #last_hiddens_kurt=kurtosis(np.array(tmp_proj.projected_states.cpu()), axis=1)
                #last_hiddens_min=np.array(torch.min(tmp_proj.projected_states, dim=1)[0].cpu())
                #last_hiddens_max=np.array(torch.max(tmp_proj.projected_states, dim=1)[0].cpu())
                #last_hiddens_proj=np.hstack((last_hiddens_avg,last_hiddens_std,last_hiddens_skew,last_hiddens_kurt,last_hiddens_min,last_hiddens_max))
               
                #features_avg=np.array(torch.mean(tmp_proj.projected_quantized_states, dim=1).cpu())
                #features_std=np.array(torch.std(tmp_proj.projected_quantized_states, dim=1).cpu())
                #features_skew=skew(np.array(tmp_proj.projected_quantized_states.cpu()), axis=1)
                #features_kurt=kurtosis(np.array(tmp_proj.projected_quantized_states.cpu()), axis=1)
                #features_min=np.array(torch.min(tmp_proj.projected_quantized_states, dim=1)[0].cpu())
                #features_max=np.array(torch.max(tmp_proj.projected_quantized_states, dim=1)[0].cpu())
                #features_proj = np.hstack((features_avg,features_std,features_skew,features_kurt,features_min,features_max))
   
        return features[0], last_hidden_states[0]
   
    except:
        print('sequence not long enough')

# %% [markdown]
# ### Testing a file

# %%
test_file = 'data/AIBO/wav/Mont_01_053_00.wav'

# %%
model_name = 'xlsr'

# %%
fs, audio=read(test_file)   
audio=(audio-np.mean(audio))/max(audio)

#device='cpu'
#if cuda:
 #   device='cuda'

#sampling_rate = fs

if model_name=='xlsr':
    feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("facebook/wav2vec2-large-xlsr-53")
    model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-large-xlsr-53").to(device)
    #model_proj = Wav2Vec2ForPreTraining.from_pretrained("facebook/wav2vec2-large-xlsr-53").to(device)
elif model_name=='base':
    feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("facebook/wav2vec2-base-960h")   
    model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h").to(device)
    #model_proj = Wav2Vec2ForPreTraining.from_pretrained("facebook/wav2vec2-base-960h").to(device)
elif model_name=='xvec':
    feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("anton-l/wav2vec2-base-superb-sv")        
    model = Wav2Vec2ForXVector.from_pretrained("anton-l/wav2vec2-base-superb-sv").to(device)
    #model_proj = Wav2Vec2ForPreTraining.from_pretrained("anton-l/wav2vec2-base-superb-sv").to(device)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_q.bias', 'quantizer.weight_proj.weight', 'quantizer.codevectors', 'project_hid.bias', 'project_hid.weight', 'project_q.weight', 'quantizer.weight_proj.bias']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
input_values = feature_extractor(np.array(audio, dtype=float), sampling_rate=fs, return_tensors="pt", padding=True).to(device).input_values
input_values_all = feature_extractor(np.array(audio, dtype=float), sampling_rate=fs, return_tensors="pt", padding=True)
   
# compute masked indices
#batch_size, raw_sequence_length = input_values.shape
#sequence_length = model._get_feat_extract_output_lengths(raw_sequence_length)
#mask_time_indices = _compute_mask_indices((batch_size, sequence_length), mask_prob=0.2, mask_length=2)
#mask_time_indices = torch.tensor(mask_time_indices, device=input_values.device, dtype=torch.long)

with torch.inference_mode():

    tmp = model(**input_values_all.to(device))
    #tmp_proj=model_proj(input_values.to(device), mask_time_indices=mask_time_indices.to(device) )

    last_hiddens_avg=np.array(torch.mean(tmp.last_hidden_state, dim=1).cpu())
    last_hiddens_std=np.array(torch.std(tmp.last_hidden_state, dim=1).cpu())
    last_hiddens_skew=skew(np.array(tmp.last_hidden_state.cpu()), axis=1)
    last_hiddens_kurt=kurtosis(np.array(tmp.last_hidden_state.cpu()), axis=1)
    last_hiddens_min=np.array(torch.min(tmp.last_hidden_state, dim=1)[0].cpu())
    last_hiddens_max=np.array(torch.max(tmp.last_hidden_state, dim=1)[0].cpu())

    last_hidden_states=np.hstack((last_hiddens_avg,last_hiddens_std,last_hiddens_skew,last_hiddens_kurt,last_hiddens_min,last_hiddens_max))

    features_avg=np.array(torch.mean(tmp.extract_features, dim=1).cpu())
    features_std=np.array(torch.std(tmp.extract_features, dim=1).cpu())
    features_skew=skew(np.array(tmp.extract_features.cpu()), axis=1)
    features_kurt=kurtosis(np.array(tmp.extract_features.cpu()), axis=1)
    features_min=np.array(torch.min(tmp.extract_features, dim=1)[0].cpu())
    features_max=np.array(torch.max(tmp.extract_features, dim=1)[0].cpu())

    features = np.hstack((features_avg,features_std,features_skew,features_kurt,features_min,features_max))

                #last_hiddens_avg=np.array(torch.mean(tmp_proj.projected_states, dim=1).cpu())
                #last_hiddens_std=np.array(torch.std(tmp_proj.projected_states, dim=1).cpu())
                #last_hiddens_skew=skew(np.array(tmp_proj.projected_states.cpu()), axis=1)
                #last_hiddens_kurt=kurtosis(np.array(tmp_proj.projected_states.cpu()), axis=1)
                #last_hiddens_min=np.array(torch.min(tmp_proj.projected_states, dim=1)[0].cpu())
                #last_hiddens_max=np.array(torch.max(tmp_proj.projected_states, dim=1)[0].cpu())
                #last_hiddens_proj=np.hstack((last_hiddens_avg,last_hiddens_std,last_hiddens_skew,last_hiddens_kurt,last_hiddens_min,last_hiddens_max))
               
                #features_avg=np.array(torch.mean(tmp_proj.projected_quantized_states, dim=1).cpu())
                #features_std=np.array(torch.std(tmp_proj.projected_quantized_states, dim=1).cpu())
                #features_skew=skew(np.array(tmp_proj.projected_quantized_states.cpu()), axis=1)
                #features_kurt=kurtosis(np.array(tmp_proj.projected_quantized_states.cpu()), axis=1)
                #features_min=np.array(torch.min(tmp_proj.projected_quantized_states, dim=1)[0].cpu())
                #features_max=np.array(torch.max(tmp_proj.projected_quantized_states, dim=1)[0].cpu())
                #features_proj = np.hstack((features_avg,features_std,features_skew,features_kurt,features_min,features_max))
     
features[0], last_hidden_states[0]
# Out:
# (array([ 0.18597536, -0.5313227 , -0.501831  , ...,  1.2320832 ,
#          4.237875  ,  1.8295366 ], dtype=float32),
#  array([-0.03731732,  0.22137754,  0.01064559, ...,  0.21591565,
#          0.01457961, -0.02043284], dtype=float32))

# %% [markdown]
# ## Creating .csv

# %%
text_file = open('data/AIBO/labels/chunk_labels_5cl_corpus.txt')
file_content = text_file.read()
#print(file_content)
text_file.close()

# %%
##data_ = text_file.decode("utf-8").split("\r\n")
data = file_content
data = data.split("\n")
for i in range(len(data)):
      data[i] = data[i].replace('_', ' ').split(" ")
#print(data)

# %%
labels_df = pd.DataFrame(data, columns=["source", "speaker", "n_rec", "num", "label", "percentage"], index=None)
labels_df['filename'] = labels_df.source + "_" + labels_df.speaker + "_" + labels_df.n_rec + "_" + labels_df.num
file_path = aibo_path + "wav/"
labels_df['path'] = file_path + labels_df['filename'] + ".wav"

# %%
labels_df
# Out:
#       source speaker n_rec   num label percentage        filename  \
# 0       Mont      01   000    00     N          1  Mont_01_000_00
# 1       Mont      01   001    00     N          1  Mont_01_001_00
# 2       Mont      01   001    01     N          1  Mont_01_001_01
# 3       Mont      01   004    00     N        0.9  Mont_01_004_00
# 4       Mont      01   005    00     N          1  Mont_01_005_00
# ...      ...     ...   ...   ...   ...        ...             ...
# 18212    Ohm      32   318    00     E        0.4   Ohm_32_318_00
# 18213    Ohm      32   319    00     E        0.6   Ohm_32_319_00
# 18214    Ohm      32   320    00     N        0.9   Ohm_32_320_00
# 18215    Ohm      32   321    00     P        0.7   Ohm_32_321_00
# 18216           None  None  None  None       None             NaN
#
#                                    path
# 0      data/AIBO/wav/Mont_01_000_00.wav
# 1      data/AIBO/wav/Mont_01_001_00.wav
# 2      data/AIBO/wav/Mont_01_001_01.wav
# 3      data/AIBO/wav/Mont_01_004_00.wav
# 4      data/AIBO/wav/Mont_01_005_00.wav
# ...                                 ...
# 18212   data/AIBO/wav/Ohm_32_318_00.wav
# 18213   data/AIBO/wav/Ohm_32_319_00.wav
# 18214   data/AIBO/wav/Ohm_32_320_00.wav
# 18215   data/AIBO/wav/Ohm_32_321_00.wav
# 18216                               NaN
#
# [18217 rows x 8 columns]

# %%
#test_file = "data/AIBO/wav/Mont_01_007_00.wav"

# %%
#fs, audio = read(test_file)

# %%
#fs

# %%
labels_df["speaker"] = pd.to_numeric(labels_df["speaker"])

# %%
labels_df.loc[labels_df.source =='Ohm', 'speaker'] = labels_df.speaker + 25

# %%
labels_dict = {'A': 0, 'E': 1, 'N': 2, 'P': 3, 'R': 4}
labels_df['lb'] = labels_df['label'].map(labels_dict)

# %% [markdown]
# ### Splitting dataset

# %%
labels_df.source.value_counts()
# Out:
# Ohm     9959
# Mont    8257
#            1
# Name: source, dtype: int64

# %%
def split_indices(last=25, split_ratio=0.7, seed=13):
    np.random.seed(seed)
    train_size = int(last * split_ratio)
    val_size = int((1 - split_ratio)/2 * last)
    test_size = last - train_size - val_size
    
    a = np.arange(1, last+1, 1)
    b = np.random.permutation(a)
    chunk_size = [train_size, val_size, test_size]
    np.cumsum(chunk_size)
    c = np.split(b, np.cumsum(chunk_size))
    train, val, test = c[0], c[1], c[2]
    if len(c[3]) > 0:
        print("some samples left unused while splitting")
    return train, val, test

# %%
last = int(max(dict((labels_df.speaker).value_counts()).keys()))
last
# Out:
# 57

# %%
train_indices, val_indices, test_indices = split_indices(last, 0.7)
split_indices(last, 0.7, 26)
# Out:
# (array([11, 10,  6, 37, 12, 57,  3, 23, 38, 40, 53, 43,  8, 44, 48, 42, 51,
#         29, 15,  1,  9, 56, 47, 21, 50, 55, 45,  4, 41, 30, 32, 52, 34, 36,
#         17, 13, 19, 28, 24]),
#  array([16, 31, 22, 25, 26, 18, 46, 35]),
#  array([ 5, 33, 27, 14, 20, 39,  2, 49,  7, 54]))

# %%
labels_df['split']=labels_df['speaker'].apply(lambda x: 'train' if x in train_indices else ('test' if x in test_indices else 'val'))

# %%
labels_df.to_csv(aibo_path + 'labels_df.csv')

# %% [markdown]
# ## Extracting .npy samplewise

# %%
labels_df = pd.read_csv(aibo_path + 'labels_df.csv', header=0, index_col=0)

# %%
len(labels_df)
# Out:
# 18217

# %%
labels_df
# Out:
#       source  speaker  n_rec  num label  percentage        filename  \
# 0       Mont      1.0    0.0  0.0     N         1.0  Mont_01_000_00
# 1       Mont      1.0    1.0  0.0     N         1.0  Mont_01_001_00
# 2       Mont      1.0    1.0  1.0     N         1.0  Mont_01_001_01
# 3       Mont      1.0    4.0  0.0     N         0.9  Mont_01_004_00
# 4       Mont      1.0    5.0  0.0     N         1.0  Mont_01_005_00
# ...      ...      ...    ...  ...   ...         ...             ...
# 18212    Ohm     57.0  318.0  0.0     E         0.4   Ohm_32_318_00
# 18213    Ohm     57.0  319.0  0.0     E         0.6   Ohm_32_319_00
# 18214    Ohm     57.0  320.0  0.0     N         0.9   Ohm_32_320_00
# 18215    Ohm     57.0  321.0  0.0     P         0.7   Ohm_32_321_00
# 18216    NaN      NaN    NaN  NaN   NaN         NaN             NaN
#
#                                    path   lb  split
# 0      data/AIBO/wav/Mont_01_000_00.wav  2.0  train
# 1      data/AIBO/wav/Mont_01_001_00.wav  2.0  train
# 2      data/AIBO/wav/Mont_01_001_01.wav  2.0  train
# 3      data/AIBO/wav/Mont_01_004_00.wav  2.0  train
# 4      data/AIBO/wav/Mont_01_005_00.wav  2.0  train
# ...                                 ...  ...    ...
# 18212   data/AIBO/wav/Ohm_32_318_00.wav  1.0  train
# 18213   data/AIBO/wav/Ohm_32_319_00.wav  1.0  train
# 18214   data/AIBO/wav/Ohm_32_320_00.wav  2.0  train
# 18215   data/AIBO/wav/Ohm_32_321_00.wav  3.0  train
# 18216                               NaN  NaN    val
#
# [18217 rows x 10 columns]

# %%
model_mode = 'xlsr'
# 'xlsr' | 'base' | 'xvec'

# %%
def w2v_path(file, split):    
    return save_path + model_mode + "_extract_features/" + split + '-' + file + '.npy'

# %%
na_files = []
problems = []

# %%
for k,v in labels_df.iterrows():
    try:
        if not isfile(v['path']):
            na_files.append(v['path'])
            print("wav for {} not available". format(v['filename']))
        elif isfile(w2v_path(v['filename'], v['split'])):
            print("w2v features found for {}".format(v['filename']))
        else:
            #ft, hs = Wav2Vec_Model(v['path'])
            ft, hs = Wav2Vec_Models(v['path'], model_name=model_mode, cuda=True)
            #np.save(save_path + "extract_features/" + v['split'] + '-' + v['filename'] + '.npy', ft)
            np.save(save_path +  model_mode + "_extract_features/" + v['split'] + '-' + v['filename'] + '.npy', ft)
            np.save(save_path +  model_mode + "_hidden_states/" + v['split'] + '-' + v['filename'] + '.npy', hs)
            print("saved")
    except:
        problems.append(v['filename'])
        print("wrong")
# Out:
# wav for Mont_01_000_00 not available
# wav for Mont_01_001_00 not available
# wav for Mont_01_001_01 not available
# wav for Mont_01_004_00 not available
# wav for Mont_01_005_00 not available
# wav for Mont_01_007_00 not available
# wav for Mont_01_008_00 not available
# wav for Mont_01_009_00 not available
# wav for Mont_01_010_00 not available
# wav for Mont_01_011_00 not available
# wav for Mont_01_012_00 not available
# wav for Mont_01_013_00 not available
# wav for Mont_01_014_00 not available
# wav for Mont_01_015_00 not available
# wav for Mont_01_016_00 not available
# wav for Mont_01_016_01 not available
# wav for Mont_01_016_02 not available
# wav for Mont_01_017_00 not available
# w2v features found for Mont_01_018_00
# wav for Mont_01_020_00 not available
# wav for Mont_01_021_00 not available
# wav for Mont_01_021_01 not available
# wav for Mont_01_022_00 not available
# wav for Mont_01_022_01 not available
# wav for Mont_01_023_00 not available
# wav for Mont_01_024_00 not available
# wav for Mont_01_025_00 not available
# wav for Mont_01_026_00 not available
# wav for Mont_01_027_00 not available
# wav for Mont_01_028_00 not available
# wav for Mont_01_029_00 not available
# wav for Mont_01_029_01 not available
# wav for Mont_01_030_00 not available
# wav for Mont_05_137_00 not available
# ...
# w2v features found for Ohm_29_229_00
# w2v features found for Ohm_29_230_00
# w2v features found for Ohm_29_231_00
# w2v features found for Ohm_29_231_01
# w2v features found for Ohm_29_232_00
# w2v features found for Ohm_29_232_01
# w2v features found for Ohm_29_232_02
# w2v features found for Ohm_29_233_00
# w2v features found for Ohm_29_234_00
# w2v features found for Ohm_29_240_00
# w2v features found for Ohm_29_241_00
# w2v features found for Ohm_29_241_01
# w2v features found for Ohm_29_241_02
# w2v features found for Ohm_29_242_00
# w2v features found for Ohm_29_242_01
# w2v features found for Ohm_29_243_00
# w2v features found for Ohm_29_244_00
# w2v features found for Ohm_29_245_00
# w2v features found for Ohm_29_246_00
# w2v features found for Ohm_29_246_01
# w2v features found for Ohm_29_247_00
# w2v features found for Ohm_29_248_00
# w2v features found for Ohm_29_249_00
# w2v features found for Ohm_29_250_00
# w2v features found for Ohm_29_250_01
# w2v features found for Ohm_29_251_00
# w2v features found for Ohm_29_252_00
# w2v features found for Ohm_29_252_01
# w2v features found for Ohm_29_253_00
# w2v features found for Ohm_29_254_00
# w2v features found for Ohm_29_255_00
# w2v features found for Ohm_29_256_00
# w2v features found for Ohm_29_257_00
# w2v features found for Ohm_29_257_01
# w2v features found for Ohm_29_258_00
# w2v features found for Ohm_29_259_00
# w2v features found for Ohm_29_260_00
# w2v features found for Ohm_29_261_00
# w2v features found for Ohm_29_262_00
# w2v features found for Ohm_29_262_01
# w2v features found for Ohm_29_263_00
# w2v features found for Ohm_29_264_00
# w2v features found for Ohm_29_265_00
# w2v features found for Ohm_29_266_00
# w2v features found for Ohm_29_266_01
# w2v features found for Ohm_29_267_00
# w2v features found for Ohm_29_268_00
# w2v features found for Ohm_29_269_00
# w2v features found for Ohm_29_270_00
# w2v features found for Ohm_29_271_00
# w2v features found for Ohm_29_272_00
# w2v features found for Ohm_29_273_00
# w2v features found for Ohm_29_274_00
# w2v features found for Ohm_29_275_00
# w2v features found for Ohm_29_276_00
# w2v features found for Ohm_29_277_00
# w2v features found for Ohm_29_278_00
# w2v features found for Ohm_29_278_01
# w2v features found for Ohm_29_278_02
# w2v features found for Ohm_29_279_00
# w2v features found for Ohm_29_279_01
# w2v features found for Ohm_29_280_00
# w2v features found for Ohm_29_281_00
# w2v features found for Ohm_29_282_00
# w2v features found for Ohm_29_283_00
# w2v features found for Ohm_29_284_00
# w2v features found for Ohm_29_284_01
# w2v features found for Ohm_29_287_00
# w2v features found for Ohm_29_288_00
# w2v features found for Ohm_29_289_00
# w2v features found for Ohm_29_290_00
# w2v features found for Ohm_29_291_00
# w2v features found for Ohm_29_292_00
# w2v features found for Ohm_29_293_00
# w2v features found for Ohm_29_294_00
# w2v features found for Ohm_29_295_00
# w2v features found for Ohm_29_295_01
# w2v features found for Ohm_29_295_02
# w2v features found for Ohm_29_295_03
# w2v features found for Ohm_29_296_00
# w2v features found for Ohm_29_296_01
# w2v features found for Ohm_29_297_00
# w2v features found for Ohm_29_298_00
# w2v features found for Ohm_29_299_00
# w2v features found for Ohm_29_299_01
# w2v features found for Ohm_29_302_00
# w2v features found for Ohm_29_303_00
# w2v features found for Ohm_29_304_00
# w2v features found for Ohm_29_305_00
# w2v features found for Ohm_29_306_00
# w2v features found for Ohm_29_306_01
# w2v features found for Ohm_29_307_00
# w2v features found for Ohm_29_309_00
# w2v features found for Ohm_29_310_00
# w2v features found for Ohm_29_311_00
# w2v features found for Ohm_29_312_00
# w2v features found for Ohm_29_312_01
# w2v features found for Ohm_29_312_02
# w2v features found for Ohm_29_313_00
# w2v features found for Ohm_29_314_00
# w2v features found for Ohm_29_315_00
# w2v features found for Ohm_29_315_01
# w2v features found for Ohm_29_316_00
# w2v features found for Ohm_29_317_00
# w2v features found for Ohm_29_321_00
# w2v features found for Ohm_29_322_00
# w2v features found for Ohm_29_323_00
# w2v features found for Ohm_29_324_00
# w2v features found for Ohm_29_325_00
# w2v features found for Ohm_29_326_00
# w2v features found for Ohm_29_327_00
# w2v features found for Ohm_29_328_00
# w2v features found for Ohm_29_328_01
# w2v features found for Ohm_29_329_00
# w2v features found for Ohm_29_330_00
# w2v features found for Ohm_29_331_00
# w2v features found for Ohm_29_332_00
# w2v features found for Ohm_29_333_00
# w2v features found for Ohm_29_334_00
# w2v features found for Ohm_29_335_00
# w2v features found for Ohm_29_336_00
# w2v features found for Ohm_29_337_00
# w2v features found for Ohm_29_338_00
# w2v features found for Ohm_29_339_00
# w2v features found for Ohm_29_340_00
# w2v features found for Ohm_29_340_01
# w2v features found for Ohm_29_340_02
# w2v features found for Ohm_29_341_00
# w2v features found for Ohm_29_342_00
# w2v features found for Ohm_29_343_00
# w2v features found for Ohm_29_344_00
# w2v features found for Ohm_29_345_00
# w2v features found for Ohm_29_346_00
# w2v features found for Ohm_29_347_00
# w2v features found for Ohm_29_348_00
# w2v features found for Ohm_29_349_00
# w2v features found for Ohm_29_350_00
# w2v features found for Ohm_29_351_00
# w2v features found for Ohm_29_351_01
# w2v features found for Ohm_29_352_00
# w2v features found for Ohm_29_352_01
# w2v features found for Ohm_29_353_00
# w2v features found for Ohm_29_354_00
# w2v features found for Ohm_29_355_00
# w2v features found for Ohm_29_356_00
# w2v features found for Ohm_29_357_00
# w2v features found for Ohm_29_358_00
# w2v features found for Ohm_29_359_00
# w2v features found for Ohm_29_359_01
# w2v features found for Ohm_31_000_00
# w2v features found for Ohm_31_001_00
# w2v features found for Ohm_31_002_00
# w2v features found for Ohm_31_003_00
# w2v features found for Ohm_31_004_00
# w2v features found for Ohm_31_005_00
# w2v features found for Ohm_31_006_00
# w2v features found for Ohm_31_006_01
# w2v features found for Ohm_31_007_00
# w2v features found for Ohm_31_008_00
# w2v features found for Ohm_31_009_00
# w2v features found for Ohm_31_009_01
# w2v features found for Ohm_31_010_00
# w2v features found for Ohm_31_011_00
# w2v features found for Ohm_31_011_01
# w2v features found for Ohm_31_011_02
# w2v features found for Ohm_31_012_00
# w2v features found for Ohm_31_013_00
# w2v features found for Ohm_31_014_00
# w2v features found for Ohm_31_014_01
# w2v features found for Ohm_31_015_00
# w2v features found for Ohm_31_016_00
# w2v features found for Ohm_31_017_00
# w2v features found for Ohm_31_017_01
# w2v features found for Ohm_31_018_00
# w2v features found for Ohm_31_018_01
# w2v features found for Ohm_31_018_02
# w2v features found for Ohm_31_018_03
# w2v features found for Ohm_31_019_00
# w2v features found for Ohm_31_019_01
# w2v features found for Ohm_31_019_02
# w2v features found for Ohm_31_019_03
# w2v features found for Ohm_31_019_04
# w2v features found for Ohm_31_019_05
# w2v features found for Ohm_31_021_00
# w2v features found for Ohm_31_022_00
# w2v features found for Ohm_31_023_00
# w2v features found for Ohm_31_024_00
# w2v features found for Ohm_31_025_00
# w2v features found for Ohm_31_025_01
# w2v features found for Ohm_31_026_00
# w2v features found for Ohm_31_028_00
# w2v features found for Ohm_31_029_00
# w2v features found for Ohm_31_029_01
# w2v features found for Ohm_31_030_00
# w2v features found for Ohm_31_031_00
# w2v features found for Ohm_31_032_00
# w2v features found for Ohm_31_033_00
# w2v features found for Ohm_31_033_01
# w2v features found for Ohm_31_033_02
# w2v features found for Ohm_31_033_03
# w2v features found for Ohm_31_033_04
# w2v features found for Ohm_31_034_00
# w2v features found for Ohm_31_034_01
# w2v features found for Ohm_31_034_02
# w2v features found for Ohm_31_035_00
# w2v features found for Ohm_31_036_00
# w2v features found for Ohm_31_037_00
# w2v features found for Ohm_31_037_01
# w2v features found for Ohm_31_037_02
# w2v features found for Ohm_31_038_00
# w2v features found for Ohm_31_040_00
# w2v features found for Ohm_31_041_00
# w2v features found for Ohm_31_042_00
# w2v features found for Ohm_31_045_00
# w2v features found for Ohm_31_046_00
# w2v features found for Ohm_31_046_01
# w2v features found for Ohm_31_046_02
# w2v features found for Ohm_31_047_00
# w2v features found for Ohm_31_047_01
# w2v features found for Ohm_31_047_02
# w2v features found for Ohm_31_048_00
# w2v features found for Ohm_31_049_00
# w2v features found for Ohm_31_049_01
# w2v features found for Ohm_31_050_00
# w2v features found for Ohm_31_050_01
# w2v features found for Ohm_31_050_02
# w2v features found for Ohm_31_050_03
# w2v features found for Ohm_31_050_04
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved
# Some weights of the model checkpoint at facebook/wav2vec2-large-xlsr-53 were not used when initializing Wav2Vec2Model: ['project_hid.bias', 'project_q.weight', 'project_q.bias', 'project_hid.weight', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# saved

# %% [markdown]
# ## Gathering .npy arrays into train/val/test with features, hidden states and layers

# %%
aibo_ft_train = []
aibo_ft_val = []
aibo_ft_test = []

# %%
aibo_hs_train = []
aibo_hs_val = []
aibo_hs_test = []

# %%
aibo_lb_train = []
aibo_lb_val = []
aibo_lb_test = []

# %%
for file in os.listdir(save_path + model_mode + "_extract_features/"):
    if file.startswith("train-"):
        #filename = file.split("-")[1]
        ft = np.load(save_path + model_mode + "_extract_features/" + file) 
        aibo_ft_train.append(ft)
    elif file.startswith("val-"):
        #filename = file.split("-")[1]
        ft = np.load(save_path + model_mode + "_extract_features/" + file) 
        aibo_ft_val.append(ft)
    else:
        ft = np.load(save_path + model_mode + "_extract_features/" + file) 
        aibo_ft_test.append(ft)        
np.save(save_path + model_mode + "_aibo_ft_train.npy", aibo_ft_train)
np.save(save_path + model_mode + "_aibo_ft_val.npy", aibo_ft_val)
np.save(save_path + model_mode + "_aibo_ft_test.npy", aibo_ft_test)

# %%
for file in os.listdir(save_path + model_mode + "_hidden_states/"):
    if file.startswith("train-"):
        #filename = file.split("-")[1]
        hs = np.load(save_path + model_mode + "_hidden_states/" + file) 
        aibo_hs_train.append(hs)
    elif file.startswith("val-"):
        #filename = file.split("-")[1]
        hs = np.load(save_path + model_mode + "_hidden_states/" + file) 
        aibo_hs_val.append(hs)
    else:
        hs = np.load(save_path + model_mode + "_hidden_states/" + file) 
        aibo_hs_test.append(hs)        
np.save(save_path + model_mode + "_aibo_hs_train.npy", aibo_hs_train)
np.save(save_path + model_mode + "_aibo_hs_val.npy", aibo_hs_val)
np.save(save_path + model_mode + "_aibo_hs_test.npy", aibo_hs_test)

# %%
labels_df.dtypes

# %%
for file in os.listdir(save_path + model_mode + "_extract_features/"):
    label = labels_df.loc[labels_df['filename'] == file.split("-")[1].split(".")[0], 'lb']
    #print(type(label))
    #print(type(int(float(label.values))))
    #print(type(str(label)))
    #lb = int(float(label.replace('\n', ' ').split(' ')[4]))
    lb = str(label)
    #lb = pd.to_string(label, index=False)
    #lb = label
    lb = int(float(lb.replace('\n', ' ').split(' ')[4]))
    if file.startswith("train-"):
        aibo_lb_train.append(lb)
    elif file.startswith("val-"):
        aibo_lb_val.append(lb)
    else:
        aibo_lb_test.append(lb)
np.save(save_path + model_mode + "_aibo_lb_train.npy", aibo_lb_train)
np.save(save_path + model_mode + "_aibo_lb_val.npy", aibo_lb_val)
np.save(save_path + model_mode + "_aibo_lb_test.npy", aibo_lb_test)

# %%
len(os.listdir(save_path + model_mode + "_extract_features/"))
# Out:
# 4566

# %%
len(aibo_lb_val)
# Out:
# 670

# %%
len(aibo_lb_train)
# Out:
# 3269

# %%
len(aibo_hs_val)
# Out:
# 670

# %%
len(aibo_lb_test)
# Out:
# 627

# %%
len(aibo_hs_test)
# Out:
# 627

# %%
aibo_lb_train[634]
# Out:
# 1

# %%
type(aibo_lb_test[0].replace)
# Out:
# str

# %%
len(aibo_lb_val)
# Out:
# 670

# %%
#str(aibo_lb_val[0]).replace('\n', ' ').split(' ')
# Out:
# ['2']

# %%
#for i in range(len(aibo_lb_val)):
 #   a = str(aibo_lb_val[i]).replace('\n', ' ').split(' ')[4]
  #  aibo_lb_val[i] = int(float(a))

# %%
type(int(float(aibo_lb_test[0])))
# Out:
# int

# %%
len(aibo_lb_train[2].split(' '))
# Out:
# 8

# %%
int(float(aibo_lb_train[2].replace('\n', ' ').split(' ')[4]))
# Out:
# 1

# %%
type(int(float(aibo_lb_train[2].replace('\n', ' ').split(' ')[4])))
# Out:
# int

# %%
#np.unique(labels)

# %%
#len(os.listdir('data/AIBO/wav/'))
# Out:
# 3547

# %%
len(na_files)
# Out:
# 14874
